# %% [markdown]
# # Scrapping: Build urls map
#
# ### Source
#
# - Medium: [How to build a URL crawler to map a website using Python](https://medium.com/swlh/how-to-build-a-url-crawler-to-map-a-website-using-python-3e7db83feb7a).

# %%
def add_local_address(url):
    if '#' in url:
        pass
    elif '.pdf' in url:
        pass
    elif 'mailto' in url:
        pass
    else:
        local_urls.add(url)

# %%
from bs4 import BeautifulSoup
import requests
import requests.exceptions
from urllib.parse import urlsplit
from urllib.parse import urlparse
from collections import deque
import re

#url = "https://jmquintana79.github.io"
#url = "https://www.jma.go.jp/jma/indexe.html"
#url = "https://www.endesa.com"
#url = "https://n-kishou.com/corp/"
#url = "https://www.ree.es/es"
#url = "https://www.meteologica.com"
url = "https://www.thomsonreuters.com/en/products-services/energy/top-100.html"
url = "https://globaledge.msu.edu/industries/energy/corporations"
# a queue of urls to be crawled
new_urls = deque([url])

# a set of urls that we have already been processed 
processed_urls = set()
# a set of domains inside the target website
local_urls = set()
# a set of domains outside the target website
foreign_urls = set()
# a set of broken urls
broken_urls = set()

# initialize counter
icount = 0
# process urls one by one until we exhaust the queue
while len(new_urls):
    # move next url from the queue to the set of processed urls
    url = new_urls.popleft()
    processed_urls.add(url)
    # get url's content
    print("Processing %s" %(url))
    try:
        response = requests.get(url)
    except (requests.exceptions.MissingSchema, requests.exceptions.ConnectionError, requests.exceptions.InvalidURL, requests.exceptions.InvalidSchema):
        # add broken urls to it's own set, then continue
        broken_urls.add(url)
        continue
    
    # extract base url to resolve relative links
    parts = urlsplit(url)
    base = "{0.netloc}".format(parts)
    strip_base = base.replace("www.", "")
    base_url = "{0.scheme}://{0.netloc}".format(parts)
    path = url[:url.rfind('/')+1] if '/' in parts.path else url

    # create a beutiful soup for the html document
    soup = BeautifulSoup(response.text, "lxml")

    for link in soup.find_all('a'):
        # extract link url from the anchor
        anchor = link.attrs["href"] if "href" in link.attrs else ''

        if anchor.startswith('/'):
            local_link = base_url + anchor
            #local_urls.add(local_link)
            add_local_address(local_link)
        elif strip_base in anchor:
            #local_urls.add(anchor)
            add_local_address(anchor)
        elif not anchor.startswith('http'):
            local_link = path + anchor
            #local_urls.add(local_link)
            add_local_address(local_link)
        else:
            foreign_urls.add(anchor)

        # only local
        for i in local_urls:
            if not i in new_urls and not i in processed_urls:
                new_urls.append(i)
    # add counter
    icount += 1
    # stop
    if icount == 1:
        break
# Out:
# Processing https://globaledge.msu.edu/industries/energy/corporations

# %%
local_urls
# Out:
# {'https://globaledge.msu.edu/',
#  'https://globaledge.msu.edu/academy',
#  'https://globaledge.msu.edu/academy/announcements',
#  'https://globaledge.msu.edu/academy/community-colleges',
#  'https://globaledge.msu.edu/academy/course-content',
#  'https://globaledge.msu.edu/academy/studyibfaq',
#  'https://globaledge.msu.edu/account/register',
#  'https://globaledge.msu.edu/blog',
#  'https://globaledge.msu.edu/comparator',
#  'https://globaledge.msu.edu/countries/argentina/corporations',
#  'https://globaledge.msu.edu/countries/australia/corporations',
#  'https://globaledge.msu.edu/countries/austria/corporations',
#  'https://globaledge.msu.edu/countries/brazil/corporations',
#  'https://globaledge.msu.edu/countries/canada/corporations',
#  'https://globaledge.msu.edu/countries/china/corporations',
#  'https://globaledge.msu.edu/countries/colombia/corporations',
#  'https://globaledge.msu.edu/countries/cyprus/corporations',
#  'https://globaledge.msu.edu/countries/czechia/corporations',
#  'https://globaledge.msu.edu/countries/denmark/corporations',
#  'https://globaledge.msu.edu/countries/finland/corporations',
#  'https://globaledge.msu.edu/countries/france/corporations',
#  'https://globaledge.msu.edu/countries/germany/corporations',
#  'https://globaledge.msu.edu/countries/hong-kong/corporations',
#  'https://globaledge.msu.edu/countries/hungary/corporations',
#  'https://globaledge.msu.edu/countries/india/corporations',
#  'https://globaledge.msu.edu/countries/ireland/corporations',
#  'https://globaledge.msu.edu/countries/israel/corporations',
#  'https://globaledge.msu.edu/countries/italy/corporations',
#  'https://globaledge.msu.edu/countries/japan/corporations',
#  'https://globaledge.msu.edu/countries/malaysia/corporations',
#  'https://globaledge.msu.edu/countries/netherlands/corporations',
#  'https://globaledge.msu.edu/countries/norway/corporations',
#  'https://globaledge.msu.edu/countries/poland/corporations',
#  'https://globaledge.msu.edu/countries/portugal/corporations',
#  'https://globaledge.msu.edu/countries/russia/corporations',
#  'https://globaledge.msu.edu/countries/saudi-arabia/corporations',
#  'https://globaledge.msu.edu/countries/singapore/corporations',
#  'https://globaledge.msu.edu/countries/south-africa/corporations',
#  'https://globaledge.msu.edu/countries/south-korea/corporations',
#  'https://globaledge.msu.edu/countries/spain/corporations',
#  'https://globaledge.msu.edu/countries/sweden/corporations',
#  'https://globaledge.msu.edu/countries/taiwan/corporations',
#  'https://globaledge.msu.edu/countries/thailand/corporations',
#  'https://globaledge.msu.edu/countries/united-kingdom/corporations',
#  'https://globaledge.msu.edu/countries/united-states/corporations',
#  'https://globaledge.msu.edu/get-connected/globaledge-business-beat',
#  'https://globaledge.msu.edu/get-connected/globaledge-business-review',
#  'https://globaledge.msu.edu/global-insights',
#  'https://globaledge.msu.edu/global-insights/by/country',
#  'https://globaledge.msu.edu/global-insights/by/econ-class',
#  'https://globaledge.msu.edu/global-insights/by/industry',
#  'https://globaledge.msu.edu/global-insights/by/state',
#  'https://globaledge.msu.edu/global-insights/by/trade-bloc',
#  'https://globaledge.msu.edu/global-resources',
#  'https://globaledge.msu.edu/industries/energy',
#  'https://globaledge.msu.edu/industries/energy/background',
#  'https://globaledge.msu.edu/industries/energy/corporations',
#  'https://globaledge.msu.edu/industries/energy/events',
#  'https://globaledge.msu.edu/industries/energy/memo',
#  'https://globaledge.msu.edu/industries/energy/regulatory-agencies',
#  'https://globaledge.msu.edu/industries/energy/resources',
#  'https://globaledge.msu.edu/industries/energy/tradestats',
#  'https://globaledge.msu.edu/international-internships',
#  'https://globaledge.msu.edu/mpi',
#  'https://globaledge.msu.edu/newsletters',
#  'https://globaledge.msu.edu/policies/copyright',
#  'https://globaledge.msu.edu/policies/disclaimer',
#  'https://globaledge.msu.edu/policies/logos',
#  'https://globaledge.msu.edu/policies/privacy',
#  'https://globaledge.msu.edu/reference-desk/export-tutorials',
#  'https://globaledge.msu.edu/reference-desk/glossary',
#  'https://globaledge.msu.edu/reference-desk/online-course-modules',
#  'https://globaledge.msu.edu/rss',
#  'https://globaledge.msu.edu/site/about',
#  'https://globaledge.msu.edu/site/history',
#  'https://globaledge.msu.edu/site/sitemap',
#  'https://globaledge.msu.edu/site/testimonials',
#  'https://globaledge.msu.edu/team',
#  'https://globaledge.msu.edu/team/aboutmsu-ibc',
#  'https://globaledge.msu.edu/team/contact',
#  'https://globaledge.msu.edu/team/partnerships',
#  'https://globaledge.msu.edu/tools-and-data/diagnostic-tools',
#  'https://globaledge.msu.edu/tools-and-data/dibs',
#  'https://globaledge.msu.edu/tools-and-data/interactive-rankings',
#  'https://globaledge.msu.edu/tools-and-data/test-your-knowledge/index'}

# %%
foreign_urls
# Out:
# {'http://ceh.cosmo-oil.co.jp/',
#  'http://en.ceec.net.cn/',
#  'http://en.cgnpc.com.cn/',
#  'http://eng.kogas-tech.co.kr/main.do',
#  'http://eng.skinnovation.com/',
#  'http://france.edf.com/',
#  'http://hollyfrontier.com/',
#  'http://interrao.ru/en/',
#  'http://ir.ennenergy.com/en/global/home.php',
#  'http://msu.edu',
#  'http://novatek.ru/en/',
#  'http://www.600795.com.cn/',
#  'http://www.aep.com/',
#  'http://www.aes.com/',
#  'http://www.agl.com.au/',
#  'http://www.alliantenergy.com',
#  'http://www.ameren.com/',
#  'http://www.atmosenergy.com/',
#  'http://www.bharatpetroleum.com/',
#  'http://www.bp.com/',
#  'http://www.caltex.com.au/',
#  'http://www.canadianutilities.com/',
#  'http://www.caosco.com',
#  'http://www.cenovus.com/',
#  'http://www.centerpointenergy.com/',
#  'http://www.centrica.com/',
#  'http://www.cez.cz',
#  'http://www.cheniere.com',
#  'http://www.chevron.com/',
#  'http://www.chinagasholdings.com.hk/',
#  'http://www.chuden.co.jp/english/index.html',
#  'http://www.clypg.com.cn/en/',
#  'http://www.cmsenergy.com/',
#  'http://www.cnnp.com.cn',
#  'http://www.cnoocengineering.com/en/',
#  'http://www.coned.com/',
#  'http://www.conocophillips.com',
#  'http://www.cpfl.com.br/ir/',
#  'http://www.cr-power.com/en/',
#  'http://www.crgas.com.hk/',
#  'http://www.cypc.com.cn/',
#  'http://www.dcc.ie/',
#  'http://www.delek-group.com/',
#  'http://www.dteenergy.com/',
#  'http://www.dtpower.com/en/',
#  'http://www.duke-energy.com/',
#  'http://www.ecopetrol.com.co/',
#  'http://www.edison.com/',
#  'http://www.edp.pt/en/Pages/homepage.aspx',
#  'http://www.eletrobras.com/',
#  'http://www.emera.com/',
#  'http://www.enbridge.com/',
#  'http://www.enbw.com/content/en/index.jsp',
#  'http://www.enel.com/en-gb/',
#  'http://www.energia.co.jp/e/',
#  'http://www.engie.com/',
#  'http://www.eni.com/en_IT/home.html',
#  'http://www.entergy.com/',
#  'http://www.eon-uk.com/',
#  'http://www.evergyinc.com/homepage',
#  'http://www.exeloncorp.com/',
#  'http://www.exxonmobil.com',
#  'http://www.forbes.com/global2000/list/',
#  'http://www.fortisinc.com/',
#  'http://www.fortive.com/',
#  'http://www.fortum.com/en/pages/default.aspx',
#  'http://www.fpcc.com.tw/English/default.htm',
#  'http://www.gailonline.com/',
#  'http://www.galpenergia.com/EN/Paginas/Home.aspx',
#  'http://www.gazprom.com/',
#  'http://www.gdi.com.hk',
#  'http://www.gkpge.pl/',
#  'http://www.halliburton.com/',
#  'http://www.hd.jx-group.co.jp/',
#  'http://www.hdpi.com.cn/',
#  'http://www.hess.com/',
#  'http://www.hpi.com.cn/sites/english/Pages/default.aspx',
#  'http://www.huskyenergy.com/',
#  'http://www.hydroone.com/',
#  'http://www.iberdrola.es/',
#  'http://www.idemitsu.com/',
#  'http://www.inpex.co.jp/english/index.html',
#  'http://www.iocl.com/',
#  'http://www.jpower.co.jp/',
#  'http://www.kepco.co.kr/eng/',
#  'http://www.kindermorgan.com/',
#  'http://www.kyuden.co.jp',
#  'http://www.lukoil.com/',
#  'http://www.marathonpetroleum.com/',
#  'http://www.mol.hu/en/',
#  'http://www.murphyoilcorp.com/',
#  'http://www.nationalgrid.com',
#  'http://www.nexteraenergyresources.com/',
#  'http://www.nisource.com/en/home.aspx',
#  'http://www.nrgenergy.com/',
#  'http://www.ntpc.co.in/',
#  'http://www.omv.com/',
#  'http://www.oneok.com/',
#  'http://www.originenergy.com.au/',
#  'http://www.orlen.pl/EN/',
#  'http://www.osakagas.co.jp/en/',
#  'http://www.oxy.com/',
#  'http://www.pbfenergy.com',
#  'http://www.pembina.com',
#  'http://www.petrobras.com.br/en/',
#  'http://www.petrochina.com.cn/ptr/',
#  'http://www.pge.com/',
#  'http://www.pgnig.pl/',
#  'http://www.phillips66.com',
#  'http://www.pinnaclewest.com/',
#  'http://www.powerassets.com/',
#  'http://www.powergridindia.com/',
#  'http://www.pplelectric.com/',
#  'http://www.pseg.com',
#  'http://www.ree.es/en',
#  'http://www.repsol.com/',
#  'http://www.ril.com/',
#  'http://www.rosneft.com/',
#  'http://www.rosseti.ru/',
#  'http://www.rwe.com/',
#  'http://www.s-oil.com/',
#  'http://www.saipem.com/',
#  'http://www.santos.com/',
#  'http://www.sasol.com/',
#  'http://www.sdicpower.com',
#  'http://www.se.com.sa/SEC/English/default.htm',
#  'http://www.sempra.com/',
#  'http://www.shell.com/',
#  'http://www.sinopecgroup.com/group/en/',
#  'http://www.sk.com/',
#  'http://www.slb.com/',
#  'http://www.snam.it/en/index.html',
#  'http://www.southerncompany.com/',
#  'http://www.suncor.com/',
#  'http://www.surgutneftegas.ru/en/',
#  'http://www.targaresources.com/',
#  'http://www.tatneft.ru/',
#  'http://www.technipfmc.com/',
#  'http://www.tepco.co.jp/en/',
#  'http://www.terna.it/',
#  'http://www.tnb.com.my/',
#  'http://www.tohoku-epco.co.jp/index-e.htm',
#  'http://www.tokyo-gas.co.jp/index_e.html',
#  'http://www.total.com/',
#  'http://www.transneft.ru',
#  'http://www.ugicorp.com',
#  'http://www.ultra.com.br/',
#  'http://www.valero.com/',
#  'http://www.verbund.com/cc/en/',
#  'http://www.wecenergygroup.com/',
#  'http://www.wfscorp.com/',
#  'http://www.williams.com/',
#  'http://www.woodside.com.au/',
#  'http://www.xcelenergy.com/',
#  'http://www.ypf.com/Paginas/Home.aspx',
#  'http://www.zzepc.com.cn',
#  'http://www1.kepco.co.jp/english/',
#  'https://broad.msu.edu/ciber',
#  'https://enplusgroup.com/en/',
#  'https://orsted.com/en',
#  'https://twitter.com/globalEDGEMSU',
#  'https://twitter.com/globaledgemsu',
#  'https://www.aramco.com/',
#  'https://www.bakerhughes.com/',
#  'https://www.clpgroup.com/',
#  'https://www.diamondbackenergy.com/',
#  'https://www.dominionenergy.com/',
#  'https://www.equinor.com/en.html',
#  'https://www.eversource.com/content/',
#  'https://www.facebook.com/globalEDGEmsu',
#  'https://www.facebook.com/globalEDGEmsu/',
#  'https://www.firstenergycorp.com/',
#  'https://www.linkedin.com/showcase/globaledgemsu/',
#  'https://www.lundin-energy.com/',
#  'https://www.naturgy.com/en/home',
#  'https://www.neste.us/',
#  'https://www.ovintiv.com/',
#  'https://www.pttplc.com/en/Home.aspx',
#  'https://www.tcenergy.com/',
#  'https://www.towngas.com/Chi/Cust/index.aspx',
#  'https://www.vedantalimited.com/Pages/Home.aspx',
#  'https://www.vistraenergy.com/'}

# %% [markdown]
# ### get foreign url base

# %%
import urllib.parse
def base_url(url, with_path=False):
    parsed = urllib.parse.urlparse(url)
    path   = '/'.join(parsed.path.split('/')[:-1]) if with_path else ''
    parsed = parsed._replace(path=path)
    parsed = parsed._replace(params='')
    parsed = parsed._replace(query='')
    parsed = parsed._replace(fragment='')
    return parsed.geturl()

# %%
# foreign urls to respective base name
list(set([base_url(url) for url in foreign_urls]))
# Out:
# ['http://www.hess.com',
#  'http://www.chinagasholdings.com.hk',
#  'http://www.repsol.com',
#  'https://www.ovintiv.com',
#  'http://www.dcc.ie',
#  'http://www.verbund.com',
#  'http://www.delek-group.com',
#  'http://www.forbes.com',
#  'http://www.ree.es',
#  'https://www.firstenergycorp.com',
#  'https://www.towngas.com',
#  'http://www.kepco.co.kr',
#  'http://www.gdi.com.hk',
#  'http://www.edison.com',
#  'http://interrao.ru',
#  'http://www.alliantenergy.com',
#  'http://www.sk.com',
#  'http://www.cypc.com.cn',
#  'http://www.surgutneftegas.ru',
#  'http://www.eletrobras.com',
#  'https://twitter.com',
#  'http://www.atmosenergy.com',
#  'http://www.chuden.co.jp',
#  'http://www.jpower.co.jp',
#  'https://www.lundin-energy.com',
#  'http://www.marathonpetroleum.com',
#  'http://www1.kepco.co.jp',
#  'http://www.exxonmobil.com',
#  'https://www.neste.us',
#  'https://www.diamondbackenergy.com',
#  'http://www.cheniere.com',
#  'http://www.ameren.com',
#  'http://www.powerassets.com',
#  'http://www.tepco.co.jp',
#  'http://www.ril.com',
#  'http://ceh.cosmo-oil.co.jp',
#  'https://www.naturgy.com',
#  'https://broad.msu.edu',
#  'http://www.600795.com.cn',
#  'http://www.iocl.com',
#  'http://www.aes.com',
#  'http://www.entergy.com',
#  'http://www.clypg.com.cn',
#  'http://www.bp.com',
#  'http://www.exeloncorp.com',
#  'http://www.chevron.com',
#  'http://www.pgnig.pl',
#  'http://www.energia.co.jp',
#  'http://www.santos.com',
#  'http://www.aep.com',
#  'http://www.iberdrola.es',
#  'http://www.wecenergygroup.com',
#  'http://www.engie.com',
#  'http://www.phillips66.com',
#  'http://www.fortum.com',
#  'https://www.clpgroup.com',
#  'http://www.targaresources.com',
#  'http://www.pplelectric.com',
#  'https://www.pttplc.com',
#  'http://www.mol.hu',
#  'http://www.tokyo-gas.co.jp',
#  'http://www.hpi.com.cn',
#  'http://www.cez.cz',
#  'https://www.facebook.com',
#  'https://www.linkedin.com',
#  'http://www.eni.com',
#  'http://www.cmsenergy.com',
#  'https://www.vistraenergy.com',
#  'http://www.enel.com',
#  'http://en.ceec.net.cn',
#  'http://www.zzepc.com.cn',
#  'http://www.kindermorgan.com',
#  'http://www.evergyinc.com',
#  'http://msu.edu',
#  'http://www.fpcc.com.tw',
#  'http://www.halliburton.com',
#  'http://www.tatneft.ru',
#  'http://www.enbridge.com',
#  'http://www.petrobras.com.br',
#  'http://www.canadianutilities.com',
#  'http://www.technipfmc.com',
#  'http://www.pembina.com',
#  'https://www.eversource.com',
#  'http://www.ntpc.co.in',
#  'http://www.cenovus.com',
#  'http://www.nrgenergy.com',
#  'https://www.bakerhughes.com',
#  'http://www.huskyenergy.com',
#  'http://www.southerncompany.com',
#  'http://hollyfrontier.com',
#  'http://www.saipem.com',
#  'http://www.valero.com',
#  'http://www.pbfenergy.com',
#  'http://www.rwe.com',
#  'http://www.sempra.com',
#  'http://www.centerpointenergy.com',
#  'http://www.cnoocengineering.com',
#  'http://ir.ennenergy.com',
#  'http://www.conocophillips.com',
#  'http://www.hd.jx-group.co.jp',
#  'http://www.cnnp.com.cn',
#  'http://www.cr-power.com',
#  'http://www.ultra.com.br',
#  'http://france.edf.com',
#  'http://www.pseg.com',
#  'http://www.hydroone.com',
#  'http://www.nisource.com',
#  'http://www.osakagas.co.jp',
#  'http://www.oxy.com',
#  'http://www.fortisinc.com',
#  'http://www.agl.com.au',
#  'http://www.snam.it',
#  'http://www.sinopecgroup.com',
#  'http://www.eon-uk.com',
#  'http://www.sasol.com',
#  'http://www.coned.com',
#  'https://enplusgroup.com',
#  'http://www.kyuden.co.jp',
#  'http://www.ecopetrol.com.co',
#  'http://www.pge.com',
#  'http://www.dtpower.com',
#  'http://www.pinnaclewest.com',
#  'https://www.vedantalimited.com',
#  'http://www.wfscorp.com',
#  'http://www.terna.it',
#  'http://www.caltex.com.au',
#  'http://www.dteenergy.com',
#  'http://www.murphyoilcorp.com',
#  'http://www.sdicpower.com',
#  'http://www.hdpi.com.cn',
#  'http://www.originenergy.com.au',
#  'http://www.orlen.pl',
#  'http://www.lukoil.com',
#  'http://www.woodside.com.au',
#  'http://www.caosco.com',
#  'http://www.edp.pt',
#  'http://www.galpenergia.com',
#  'http://www.nationalgrid.com',
#  'http://www.s-oil.com',
#  'http://eng.kogas-tech.co.kr',
#  'http://eng.skinnovation.com',
#  'http://www.tohoku-epco.co.jp',
#  'http://www.rosneft.com',
#  'http://www.gailonline.com',
#  'http://www.rosseti.ru',
#  'http://www.emera.com',
#  'https://www.dominionenergy.com',
#  'http://www.ugicorp.com',
#  'http://www.gkpge.pl',
#  'http://www.duke-energy.com',
#  'http://www.williams.com',
#  'http://www.fortive.com',
#  'https://www.aramco.com',
#  'http://www.xcelenergy.com',
#  'http://en.cgnpc.com.cn',
#  'http://www.bharatpetroleum.com',
#  'http://www.transneft.ru',
#  'http://www.gazprom.com',
#  'http://www.total.com',
#  'http://www.se.com.sa',
#  'http://www.inpex.co.jp',
#  'http://www.enbw.com',
#  'https://www.equinor.com',
#  'http://www.idemitsu.com',
#  'http://www.ypf.com',
#  'http://www.oneok.com',
#  'https://orsted.com',
#  'http://www.nexteraenergyresources.com',
#  'http://www.shell.com',
#  'http://www.cpfl.com.br',
#  'http://www.slb.com',
#  'http://www.powergridindia.com',
#  'http://www.petrochina.com.cn',
#  'http://www.centrica.com',
#  'http://www.crgas.com.hk',
#  'http://www.omv.com',
#  'http://www.tnb.com.my',
#  'https://www.tcenergy.com',
#  'http://novatek.ru',
#  'http://www.suncor.com']
