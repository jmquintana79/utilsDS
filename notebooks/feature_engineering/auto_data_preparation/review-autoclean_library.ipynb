# %% [markdown]
# # Review - AutoClean library
#
# ### References
# - [PyPi Docs *py-AutoClean*](https://pypi.org/project/py-AutoClean/)

# %% [raw]
# !pip install py-AutoClean

# %%
from AutoClean import AutoClean
import seaborn as sns
import numpy as np

# %% [markdown]
# ### load data

# %%
df = sns.load_dataset('planets')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.loc[df["mass"] == 7.10, "orbital_period"] = np.nan
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1             NaN   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ### Auto cleaning

# %%
AutoClean?
# Out:
# Init signature:
# AutoClean(
#     input_data,
#     mode='auto',
#     duplicates=False,
#     missing_num=False,
#     missing_categ=False,
#     encode_categ=False,
#     extract_datetime=False,
#     outliers=False,
#     outlier_param=1.5,
#     logfile=True,
#     verbose=False,
# )
# Docstring:      <no docstring>
# Init docstring:
# input_data (dataframe)..........Pandas dataframe
# mode (str)......................define in which mode you want to run AutoClean
#                                 'auto' = sets all parameters to 'auto' and let AutoClean do the data cleaning automatically
#                                 'manual' = lets you choose which parameters/cleaning steps you want to perform
#
# duplicates (str)................define if duplicates in the data should be handled
#                                 duplicates are rows where all features are identical
#                                 'auto' = automated handling, deletes all copies of duplicates except one
# ...

# %%
pipeline = AutoClean(df, mode='auto', verbose = True)
# Out:
# 06-07-2023 18:44:30.08 - INFO - Started validation of input parameters...
# 06-07-2023 18:44:30.09 - INFO - Completed validation of input parameters
# 06-07-2023 18:44:30.09 - INFO - Started handling of duplicates... Method: "AUTO"
# 06-07-2023 18:44:30.10 - DEBUG - Deletion of 4 duplicate(s) succeeded
# 06-07-2023 18:44:30.10 - INFO - Completed handling of duplicates in 0.005927 seconds
# 06-07-2023 18:44:30.10 - INFO - Started handling of missing values...
# 06-07-2023 18:44:30.11 - INFO - Found a total of 782 missing value(s)
# 06-07-2023 18:44:30.11 - INFO - Started handling of NUMERICAL missing values... Method: "AUTO"
# 06-07-2023 18:44:30.15 - DEBUG - LINREG imputation of 1 value(s) succeeded for feature "orbital_period"
# 06-07-2023 18:44:30.21 - DEBUG - LINREG imputation of 278 value(s) succeeded for feature "mass"
# 06-07-2023 18:44:30.25 - DEBUG - LINREG imputation of 15 value(s) succeeded for feature "distance"
# ...

# %%
dir(pipeline)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_clean_data',
#  '_initialize_logger',
#  '_validate_params',
#  'count_missing',
#  'duplicates',
#  'encode_categ',
#  'extract_datetime',
#  'missing_categ',
#  'missing_num',
#  'mode',
#  'outlier_param',
#  'outliers',
#  'output']

# %%
pipeline.output
# Out:
#                method  number  orbital_period       mass  distance  year  \
# 0     Radial Velocity       1      476.553352   7.100000     77.40  2006
# 1     Radial Velocity       1      874.774000   2.210000     56.95  2008
# 2     Radial Velocity       1      763.000000   2.600000     19.84  2011
# 3     Radial Velocity       1      326.030000  19.400000    110.62  2007
# 4     Radial Velocity       1      516.220000  10.500000    119.47  2009
# ...               ...     ...             ...        ...       ...   ...
# 1026          Transit       1        3.941507   4.582361    172.00  2006
# 1027          Transit       1        2.615864   2.560458    148.00  2007
# 1028          Transit       1        3.191524   3.970132    174.00  2007
# 1029          Transit       1        4.125083  24.747639    293.00  2008
# 1030          Transit       1        4.187757  14.187916    260.00  2008
#
#       method_Astrometry  method_Eclipse Timing Variations  method_Imaging  \
# ...
