# %% [markdown]
# # EDA: describe
#
# Es una ampliacion de la informacion descriptiva del metodo *describe()* de *Pandas*.

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
from analysis import describe_numeric, describe_categorical, info

# %% [markdown]
# ---
# ## load *Iris* data

# %%
# load dataset
dataset = load_iris()
dataset.keys()
# dataset to df
data = pd.DataFrame(dataset.data, columns = dataset.feature_names)
data['class'] = dataset.target
dclass = dict()
for i, ic in enumerate(dataset.target_names):
    dclass[i] = ic
data['class'] = data['class'].map(dclass)

# %% [markdown]
# # descriptive analysis: *Iris*

# %%
info(data)
# Out:
#                      dtype  unique  magnitude  %nan  num_records
# variable
# class               object     3.0        NaN   0.0          150
# sepal length (cm)  float64     NaN        0.0   0.0          150
# sepal width (cm)   float64     NaN        0.0   0.0          150
# petal length (cm)  float64     NaN        0.0   0.0          150
# petal width (cm)   float64     NaN        0.0   0.0          150

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
#                    count  mean   std  min    5%  25%   50%  75%   95%  max  \
# sepal length (cm)    150  5.84  0.83  4.3  4.60  5.1  5.80  6.4  7.25  7.9
# sepal width (cm)     150  3.06  0.44  2.0  2.34  2.8  3.00  3.3  3.80  4.4
# petal length (cm)    150  3.76  1.77  1.0  1.30  1.6  4.35  5.1  6.10  6.9
# petal width (cm)     150  1.20  0.76  0.1  0.20  0.3  1.30  1.8  2.30  2.5
#
#                    %nan  kurtosis  skew  magnitude  uniform  gaussian  \
# sepal length (cm)   0.0     -0.57  0.31          0    False     False
# sepal width (cm)    0.0      0.18  0.32          0    False      True
# petal length (cm)   0.0     -1.40 -0.27          0    False     False
# petal width (cm)    0.0     -1.34 -0.10          0    False     False
#
#                    unimodal
# sepal length (cm)      True
# sepal width (cm)       True
# petal length (cm)     False
# petal width (cm)       True

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data, max_size_cats = 3, alpha = .05)
dfc
# Out:
#       count unique  %nan  uniform     value0      value1  value2 %value0  \
# var
# class   150      3   0.0     True  virginica  versicolor  setosa   33.33
#
#       %value1 %value2
# var
# class   33.33   33.33

# %% [markdown]
# ---
# ## load *Titanic* data

# %%
import seaborn
data = seaborn.load_dataset('titanic')
data.shape
# Out:
# (891, 15)

# %% [markdown]
# # descriptive analysis: *Titanic*

# %%
info(data)
# Out:
#                 dtype  unique  magnitude   %nan  num_records
# variable
# deck         category     8.0        NaN  77.22          203
# sibsp           int64     7.0        NaN   0.00          891
# parch           int64     7.0        NaN   0.00          891
# embarked       object     4.0        NaN   0.22          889
# embark_town    object     4.0        NaN   0.22          889
# pclass          int64     3.0        NaN   0.00          891
# class        category     3.0        NaN   0.00          891
# who            object     3.0        NaN   0.00          891
# survived        int64     2.0        NaN   0.00          891
# sex            object     2.0        NaN   0.00          891
# adult_male       bool     2.0        NaN   0.00          891
# alive          object     2.0        NaN   0.00          891
# alone            bool     2.0        NaN   0.00          891
# age           float64     NaN        1.0  19.87          714
# fare          float64     NaN        1.0   0.00          891

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
#       count  mean    std   min    5%    25%    50%   75%     95%     max  \
# age     714  29.7  14.53  0.42  4.00  20.12  28.00  38.0   56.00   80.00
# fare    891  32.2  49.69  0.00  7.22   7.91  14.45  31.0  112.08  512.33
#
#        %nan  kurtosis  skew  magnitude  uniform  gaussian  unimodal
# age   19.87      0.17  0.39          1    False     False      True
# fare   0.00     33.20  4.78          1    False     False      True

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data.copy(), max_size_cats = 4, alpha = .05)
dfc
# Out:
#             count unique   %nan  uniform       value0     value1      value2  \
# var
# survived      891      2   0.00    False            0          1
# pclass        891      3   0.00    False            3          1           2
# sex           891      2   0.00    False         male     female
# sibsp         891      7   0.00    False            0          1           2
# parch         891      7   0.00    False            0          1           2
# embarked      889      3   0.22    False            S          C           Q
# class         891      3   0.00    False        Third      First      Second
# who           891      3   0.00    False          man      woman       child
# adult_male    891      2   0.00    False         True      False
# deck          203      7  77.22    False            C          B           D
# embark_town   889      3   0.22    False  Southampton  Cherbourg  Queenstown
# alive         891      2   0.00    False           no        yes
# alone         891      2   0.00    False         True      False
#
#              value3 %value0 %value1 %value2 %value3
# var
# survived              61.62   38.38
# pclass                55.11   24.24   20.65
# sex                   64.76   35.24
# sibsp        others   68.24   23.46    3.14    5.17
# parch        others   76.09   13.24    8.98    1.68
# embarked              72.44    18.9    8.66
# class                 55.11   24.24   20.65
# who                   60.27   30.42    9.32
# adult_male            60.27   39.73
# deck         others   29.06   23.15   16.26   31.52
# embark_town           72.44    18.9    8.66
# alive                 61.62   38.38
# alone                 60.27   39.73

# %% [markdown]
# ---
# ## load *Tips* data

# %%
import seaborn
data = seaborn.load_dataset('tips')
data.shape
# Out:
# (244, 7)

# %% [markdown]
# # descriptive analysis: *Tips*

# %%
info(data)
# Out:
#                dtype  unique  magnitude  %nan  num_records
# variable
# size           int64     6.0        NaN   0.0          244
# day         category     4.0        NaN   0.0          244
# sex         category     2.0        NaN   0.0          244
# smoker      category     2.0        NaN   0.0          244
# time        category     2.0        NaN   0.0          244
# total_bill   float64     NaN        1.0   0.0          244
# tip          float64     NaN        0.0   0.0          244

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
#             count   mean   std   min    5%    25%   50%    75%    95%    max  \
# total_bill    244  19.79  8.90  3.07  9.56  13.35  17.8  24.13  38.06  50.81
# tip           244   3.00  1.38  1.00  1.44   2.00   2.9   3.56   5.20  10.00
#
#             %nan  kurtosis  skew  magnitude  uniform  gaussian  unimodal
# total_bill   0.0      1.17  1.13          1    False     False      True
# tip          0.0      3.55  1.46          0    False     False     False

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data, max_size_cats = 6, alpha = .05)
dfc
# Out:
#        count unique  %nan  uniform  value0  value1 value2 value3 value4  \
# var
# sex      244      2   0.0    False    Male  Female
# smoker   244      2   0.0     True      No     Yes
# day      244      4   0.0    False     Sat     Sun   Thur    Fri
# time     244      2   0.0    False  Dinner   Lunch
# size     244      6   0.0    False       2       3      4      5      6
#
#        value5 %value0 %value1 %value2 %value3 %value4 %value5
# var
# sex             64.34   35.66
# smoker          61.89   38.11
# day             35.66   31.15   25.41    7.79
# time            72.13   27.87
# size        1   63.93   15.57   15.16    2.05    1.64    1.64

# %% [markdown]
# ---
# ## load *Wine* data

# %%
from sklearn import datasets
df = datasets.load_wine()
data = pd.DataFrame(data= np.c_[df['data'], df['target']],columns= list(df['feature_names']) + ['target'])
data['target'] = data['target'].apply(lambda x: df['target_names'][int(x)])
data.shape
# Out:
# (178, 14)

# %% [markdown]
# # descriptive analysis: *Wine*

# %%
info(data)
# Out:
#                                 dtype  unique  magnitude  %nan  num_records
# variable
# target                         object     3.0        NaN   0.0          178
# alcohol                       float64     NaN        1.0   0.0          178
# malic_acid                    float64     NaN        0.0   0.0          178
# ash                           float64     NaN        0.0   0.0          178
# alcalinity_of_ash             float64     NaN        1.0   0.0          178
# magnesium                     float64     NaN        1.0   0.0          178
# total_phenols                 float64     NaN        0.0   0.0          178
# flavanoids                    float64     NaN        0.0   0.0          178
# nonflavanoid_phenols          float64     NaN       -1.0   0.0          178
# proanthocyanins               float64     NaN        0.0   0.0          178
# color_intensity               float64     NaN        0.0   0.0          178
# hue                           float64     NaN       -1.0   0.0          178
# od280/od315_of_diluted_wines  float64     NaN        0.0   0.0          178
# proline                       float64     NaN        2.0   0.0          178

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
#                               count    mean     std     min      5%     25%  \
# alcohol                         178   13.00    0.81   11.03   11.66   12.36
# malic_acid                      178    2.34    1.12    0.74    1.06    1.60
# ash                             178    2.37    0.27    1.36    1.92    2.21
# alcalinity_of_ash               178   19.49    3.34   10.60   14.77   17.20
# magnesium                       178   99.74   14.28   70.00   80.85   88.00
# total_phenols                   178    2.30    0.63    0.98    1.38    1.74
# flavanoids                      178    2.03    1.00    0.34    0.55    1.20
# nonflavanoid_phenols            178    0.36    0.12    0.13    0.19    0.27
# proanthocyanins                 178    1.59    0.57    0.41    0.73    1.25
# color_intensity                 178    5.06    2.32    1.28    2.11    3.22
# hue                             178    0.96    0.23    0.48    0.57    0.78
# od280/od315_of_diluted_wines    178    2.61    0.71    1.27    1.46    1.94
# proline                         178  746.89  314.91  278.00  354.55  500.50
#
#                                  50%     75%      95%      max  %nan  \
# alcohol                        13.05   13.68    14.22    14.83   0.0
# malic_acid                      1.87    3.08     4.46     5.80   0.0
# ash                             2.36    2.56     2.74     3.23   0.0
# alcalinity_of_ash              19.50   21.50    25.00    30.00   0.0
# magnesium                      98.00  107.00   124.30   162.00   0.0
# total_phenols                   2.36    2.80     3.27     3.88   0.0
# flavanoids                      2.13    2.88     3.50     5.08   0.0
# nonflavanoid_phenols            0.34    0.44     0.60     0.66   0.0
# proanthocyanins                 1.56    1.95     2.71     3.58   0.0
# color_intensity                 4.69    6.20     9.60    13.00   0.0
# hue                             0.96    1.12     1.28     1.71   0.0
# od280/od315_of_diluted_wines    2.78    3.17     3.58     4.00   0.0
# proline                       673.50  985.00  1297.25  1680.00   0.0
#
#                               kurtosis  skew  magnitude  uniform  gaussian  \
# alcohol                          -0.86 -0.05          1    False     False
# malic_acid                        0.26  1.03          0    False     False
# ash                               1.08 -0.18          0    False     False
# alcalinity_of_ash                 0.44  0.21          1    False      True
# magnesium                         2.01  1.09          1    False     False
# total_phenols                    -0.85  0.09          0    False     False
# flavanoids                       -0.89  0.03          0    False     False
# nonflavanoid_phenols             -0.65  0.45         -1     True     False
# proanthocyanins                   0.51  0.51          0    False     False
# color_intensity                   0.34  0.86          0    False     False
# hue                              -0.37  0.02         -1    False     False
# od280/od315_of_diluted_wines     -1.09 -0.30          0    False     False
# proline                          -0.27  0.76          2    False     False
#
#                               unimodal
# alcohol                           True
# malic_acid                        True
# ash                               True
# alcalinity_of_ash                 True
# magnesium                         True
# total_phenols                     True
# flavanoids                        True
# nonflavanoid_phenols              True
# proanthocyanins                   True
# color_intensity                   True
# hue                               True
# od280/od315_of_diluted_wines      True
# proline                           True

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data, max_size_cats = 3, alpha = .05)
dfc
# Out:
#        count unique  %nan  uniform   value0   value1   value2 %value0 %value1  \
# var
# target   178      3   0.0     True  class_1  class_0  class_2   39.89   33.15
#
#        %value2
# var
# target   26.97
