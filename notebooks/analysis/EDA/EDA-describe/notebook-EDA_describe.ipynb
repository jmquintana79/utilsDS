# %% [markdown]
# # EDA: describe
#
# Es una ampliacion de la informacion descriptiva del metodo *describe()* de *Pandas*.

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.datasets import load_iris
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 99
import numpy as np
from datetime import datetime
from analysis import describe_numeric, describe_categorical, info, describe_datetime, describe_bivariate

# %% [markdown]
# ---
# ## LOAD *Iris* data

# %%
# load dataset
dataset = load_iris()
dataset.keys()
# dataset to df
data = pd.DataFrame(dataset.data, columns = dataset.feature_names)
data['class'] = dataset.target
dclass = dict()
for i, ic in enumerate(dataset.target_names):
    dclass[i] = ic
data['class'] = data['class'].map(dclass)

# %% [markdown]
# # descriptive analysis: *Iris*

# %%
info(data)
# Out:
#                      types  unique  magnitude  %nan  num_records
# variable
# sepal length (cm)  float64     NaN        0.0   0.0          150
# sepal width (cm)   float64     NaN        0.0   0.0          150
# petal length (cm)  float64     NaN        0.0   0.0          150
# petal width (cm)   float64     NaN        0.0   0.0          150
# class               object     3.0        NaN   0.0          150

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
#                    count  mean   std  min    5%  25%   50%  75%   95%  max  \
# sepal length (cm)    150  5.84  0.83  4.3  4.60  5.1  5.80  6.4  7.25  7.9
# sepal width (cm)     150  3.06  0.44  2.0  2.34  2.8  3.00  3.3  3.80  4.4
# petal length (cm)    150  3.76  1.77  1.0  1.30  1.6  4.35  5.1  6.10  6.9
# petal width (cm)     150  1.20  0.76  0.1  0.20  0.3  1.30  1.8  2.30  2.5
#
#                    kurtosis  skew  uniform  gaussian  unimodal
# sepal length (cm)     -0.57  0.31    False     False      True
# sepal width (cm)       0.18  0.32    False      True      True
# petal length (cm)     -1.40 -0.27    False     False     False
# petal width (cm)      -1.34 -0.10    False     False      True

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data, max_size_cats = 3, alpha = .05)
dfc
# Out:
#       count unique  uniform  value0     value1      value2 %value0 %value1  \
# var
# class   150      3     True  setosa  virginica  versicolor   33.33   33.33
#
#       %value2
# var
# class   33.33

# %% [markdown]
# ### bivariate relationship

# %%
describe_bivariate(data)
# Out:
#            variable1          variable2 depend_corr_linear  corr_linear  \
# 0  sepal length (cm)   sepal width (cm)               True        -0.22
# 1  sepal length (cm)  petal length (cm)               True         0.88
# 2  sepal length (cm)   petal width (cm)               True         0.84
# 3   sepal width (cm)  petal length (cm)               True        -0.52
# 4   sepal width (cm)   petal width (cm)               True        -0.41
# 5  petal length (cm)   petal width (cm)               True         0.96
# 0              class  petal length (cm)                NaN          NaN
# 1              class   petal width (cm)                NaN          NaN
# 2              class  sepal length (cm)                NaN          NaN
# 3              class   sepal width (cm)                NaN          NaN
#
#    corr_non_linear depend_chi2 samples_same_dist_anova
# 0             0.32         NaN                     NaN
# 1             0.77         NaN                     NaN
# 2             0.72         NaN                     NaN
# 3             0.43         NaN                     NaN
# 4             0.45         NaN                     NaN
# 5             0.85         NaN                     NaN
# 0              NaN         NaN                    True
# 1              NaN         NaN                    True
# 2              NaN         NaN                    True
# 3              NaN         NaN                    True

# %% [markdown]
# ---
# ## LOAD *Titanic* data

# %%
import seaborn
data = seaborn.load_dataset('titanic')
data.shape
# Out:
# (891, 15)

# %% [markdown]
# # descriptive analysis: *Titanic*

# %%
dfinfo = info(data)
dfinfo
# Out:
#                 types  unique  magnitude   %nan  num_records
# variable
# adult_male       bool     2.0        NaN   0.00          891
# alone            bool     2.0        NaN   0.00          891
# class        category     3.0        NaN   0.00          891
# deck         category     8.0        NaN  77.22          203
# age           float64     NaN        1.0  19.87          714
# fare          float64     NaN        1.0   0.00          891
# survived        int64     2.0        NaN   0.00          891
# pclass          int64     3.0        NaN   0.00          891
# sibsp           int64     7.0        NaN   0.00          891
# parch           int64     7.0        NaN   0.00          891
# sex            object     2.0        NaN   0.00          891
# embarked       object     4.0        NaN   0.22          889
# who            object     3.0        NaN   0.00          891
# embark_town    object     4.0        NaN   0.22          889
# alive          object     2.0        NaN   0.00          891

# %%
# int to str (cat)
for col in dfinfo[dfinfo.types=='int64'].index.tolist():
    data[col] = data[col].astype(str)

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
#       count  mean    std   min    5%    25%    50%   75%     95%     max  \
# age     714  29.7  14.53  0.42  4.00  20.12  28.00  38.0   56.00   80.00
# fare    891  32.2  49.69  0.00  7.22   7.91  14.45  31.0  112.08  512.33
#
#       kurtosis  skew  uniform  gaussian  unimodal
# age       0.17  0.39    False     False      True
# fare     33.20  4.78    False     False      True

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data.copy(), max_size_cats = 4, alpha = .05)
dfc
# Out:
#             count unique  uniform       value0     value1      value2  value3  \
# var
# survived      891      2    False            0          1
# pclass        891      3    False            3          1           2
# sex           891      2    False         male     female
# sibsp         891      7    False            0          1           2  others
# parch         891      7    False            0          1           2  others
# embarked      889      3    False            S          C           Q
# class         891      3    False        Third      First      Second
# who           891      3    False          man      woman       child
# adult_male    891      2    False         True      False
# deck          203      7    False            C          B           D  others
# embark_town   889      3    False  Southampton  Cherbourg  Queenstown
# alive         891      2    False           no        yes
# alone         891      2    False         True      False
#
#             %value0 %value1 %value2 %value3
# var
# survived      61.62   38.38
# pclass        55.11   24.24   20.65
# sex           64.76   35.24
# sibsp         68.24   23.46    3.14    5.17
# parch         76.09   13.24    8.98    1.68
# embarked      72.44    18.9    8.66
# class         55.11   24.24   20.65
# who           60.27   30.42    9.32
# adult_male    60.27   39.73
# deck          29.06   23.15   16.26   31.52
# embark_town   72.44    18.9    8.66
# alive         61.62   38.38
# alone         60.27   39.73

# %% [markdown]
# ### bivariate relationship

# %%
describe_bivariate(data)
# Out:
#       variable1    variable2 depend_corr_linear  corr_linear  corr_non_linear  \
# 0           age         fare               True          0.1              0.2
# 0      survived       pclass                NaN          NaN              NaN
# 1      survived          sex                NaN          NaN              NaN
# 2      survived        sibsp                NaN          NaN              NaN
# 3      survived        parch                NaN          NaN              NaN
# 4      survived     embarked                NaN          NaN              NaN
# 5      survived        class                NaN          NaN              NaN
# 6      survived          who                NaN          NaN              NaN
# 7      survived   adult_male                NaN          NaN              NaN
# 8      survived         deck                NaN          NaN              NaN
# 9      survived  embark_town                NaN          NaN              NaN
# 10     survived        alive                NaN          NaN              NaN
# 11     survived        alone                NaN          NaN              NaN
# 12       pclass          sex                NaN          NaN              NaN
# 13       pclass        sibsp                NaN          NaN              NaN
# 14       pclass        parch                NaN          NaN              NaN
# 15       pclass     embarked                NaN          NaN              NaN
# 16       pclass        class                NaN          NaN              NaN
# 17       pclass          who                NaN          NaN              NaN
# 18       pclass   adult_male                NaN          NaN              NaN
# 19       pclass         deck                NaN          NaN              NaN
# 20       pclass  embark_town                NaN          NaN              NaN
# 21       pclass        alive                NaN          NaN              NaN
# 22       pclass        alone                NaN          NaN              NaN
# 23          sex        sibsp                NaN          NaN              NaN
# 24          sex        parch                NaN          NaN              NaN
# 25          sex     embarked                NaN          NaN              NaN
# 26          sex        class                NaN          NaN              NaN
# 27          sex          who                NaN          NaN              NaN
# 28          sex   adult_male                NaN          NaN              NaN
# 29          sex         deck                NaN          NaN              NaN
# 30          sex  embark_town                NaN          NaN              NaN
# 31          sex        alive                NaN          NaN              NaN
# 32          sex        alone                NaN          NaN              NaN
# 33        sibsp        parch                NaN          NaN              NaN
# 34        sibsp     embarked                NaN          NaN              NaN
# 35        sibsp        class                NaN          NaN              NaN
# 36        sibsp          who                NaN          NaN              NaN
# 37        sibsp   adult_male                NaN          NaN              NaN
# 38        sibsp         deck                NaN          NaN              NaN
# 39        sibsp  embark_town                NaN          NaN              NaN
# 40        sibsp        alive                NaN          NaN              NaN
# 41        sibsp        alone                NaN          NaN              NaN
# 42        parch     embarked                NaN          NaN              NaN
# 43        parch        class                NaN          NaN              NaN
# 44        parch          who                NaN          NaN              NaN
# 45        parch   adult_male                NaN          NaN              NaN
# 46        parch         deck                NaN          NaN              NaN
# 47        parch  embark_town                NaN          NaN              NaN
# 48        parch        alive                NaN          NaN              NaN
# 49        parch        alone                NaN          NaN              NaN
# 50     embarked        class                NaN          NaN              NaN
# 51     embarked          who                NaN          NaN              NaN
# 52     embarked   adult_male                NaN          NaN              NaN
# 53     embarked         deck                NaN          NaN              NaN
# 54     embarked  embark_town                NaN          NaN              NaN
# 55     embarked        alive                NaN          NaN              NaN
# 56     embarked        alone                NaN          NaN              NaN
# 57        class          who                NaN          NaN              NaN
# 58        class   adult_male                NaN          NaN              NaN
# 59        class         deck                NaN          NaN              NaN
# 60        class  embark_town                NaN          NaN              NaN
# 61        class        alive                NaN          NaN              NaN
# 62        class        alone                NaN          NaN              NaN
# 63          who   adult_male                NaN          NaN              NaN
# 64          who         deck                NaN          NaN              NaN
# 65          who  embark_town                NaN          NaN              NaN
# 66          who        alive                NaN          NaN              NaN
# 67          who        alone                NaN          NaN              NaN
# 68   adult_male         deck                NaN          NaN              NaN
# 69   adult_male  embark_town                NaN          NaN              NaN
# 70   adult_male        alive                NaN          NaN              NaN
# 71   adult_male        alone                NaN          NaN              NaN
# 72         deck  embark_town                NaN          NaN              NaN
# 73         deck        alive                NaN          NaN              NaN
# 74         deck        alone                NaN          NaN              NaN
# 75  embark_town        alive                NaN          NaN              NaN
# 76  embark_town        alone                NaN          NaN              NaN
# 77        alive        alone                NaN          NaN              NaN
# 0    adult_male          age                NaN          NaN              NaN
# 1    adult_male         fare                NaN          NaN              NaN
# 2         alive          age                NaN          NaN              NaN
# 3         alive         fare                NaN          NaN              NaN
# 4         alone          age                NaN          NaN              NaN
# 5         alone         fare                NaN          NaN              NaN
# 6         class          age                NaN          NaN              NaN
# 7         class         fare                NaN          NaN              NaN
# 8          deck          age                NaN          NaN              NaN
# 9          deck         fare                NaN          NaN              NaN
# 10  embark_town          age                NaN          NaN              NaN
# 11  embark_town         fare                NaN          NaN              NaN
# 12     embarked          age                NaN          NaN              NaN
# 13     embarked         fare                NaN          NaN              NaN
# 14        parch          age                NaN          NaN              NaN
# 15        parch         fare                NaN          NaN              NaN
# 16       pclass          age                NaN          NaN              NaN
# 17       pclass         fare                NaN          NaN              NaN
# 18          sex          age                NaN          NaN              NaN
# 19          sex         fare                NaN          NaN              NaN
# 20        sibsp          age                NaN          NaN              NaN
# 21        sibsp         fare                NaN          NaN              NaN
# 22     survived          age                NaN          NaN              NaN
# 23     survived         fare                NaN          NaN              NaN
# 24          who          age                NaN          NaN              NaN
# 25          who         fare                NaN          NaN              NaN
#
#    depend_chi2 samples_same_dist_anova
# 0          NaN                     NaN
# 0         True                     NaN
# 1         True                     NaN
# 2         True                     NaN
# 3         True                     NaN
# 4         True                     NaN
# 5         True                     NaN
# 6         True                     NaN
# 7         True                     NaN
# 8        False                     NaN
# 9         True                     NaN
# 10        True                     NaN
# 11        True                     NaN
# 12        True                     NaN
# 13        True                     NaN
# 14       False                     NaN
# 15        True                     NaN
# 16        True                     NaN
# 17        True                     NaN
# 18        True                     NaN
# 19        True                     NaN
# 20        True                     NaN
# 21        True                     NaN
# 22        True                     NaN
# 23        True                     NaN
# 24        True                     NaN
# 25        True                     NaN
# 26        True                     NaN
# 27        True                     NaN
# 28        True                     NaN
# 29        True                     NaN
# 30        True                     NaN
# 31        True                     NaN
# 32        True                     NaN
# 33        True                     NaN
# 34        True                     NaN
# 35        True                     NaN
# 36        True                     NaN
# 37        True                     NaN
# 38       False                     NaN
# 39        True                     NaN
# 40        True                     NaN
# 41        True                     NaN
# 42       False                     NaN
# 43       False                     NaN
# 44        True                     NaN
# 45        True                     NaN
# 46        True                     NaN
# 47       False                     NaN
# 48        True                     NaN
# 49        True                     NaN
# 50        True                     NaN
# 51        True                     NaN
# 52        True                     NaN
# 53       False                     NaN
# 54        True                     NaN
# 55        True                     NaN
# 56        True                     NaN
# 57        True                     NaN
# 58        True                     NaN
# 59        True                     NaN
# 60        True                     NaN
# 61        True                     NaN
# 62        True                     NaN
# 63        True                     NaN
# 64        True                     NaN
# 65        True                     NaN
# 66        True                     NaN
# 67        True                     NaN
# 68        True                     NaN
# 69        True                     NaN
# 70        True                     NaN
# 71        True                     NaN
# 72       False                     NaN
# 73       False                     NaN
# 74        True                     NaN
# 75        True                     NaN
# 76        True                     NaN
# 77        True                     NaN
# 0          NaN                    True
# 1          NaN                    True
# 2          NaN                   False
# 3          NaN                    True
# 4          NaN                    True
# 5          NaN                    True
# 6          NaN                    True
# 7          NaN                    True
# 8          NaN                    True
# 9          NaN                    True
# 10         NaN                   False
# 11         NaN                    True
# 12         NaN                   False
# 13         NaN                    True
# 14         NaN                    True
# 15         NaN                    True
# 16         NaN                    True
# 17         NaN                    True
# 18         NaN                   False
# 19         NaN                    True
# 20         NaN                    True
# 21         NaN                    True
# 22         NaN                   False
# 23         NaN                    True
# 24         NaN                    True
# 25         NaN                    True

# %% [markdown]
# ---
# ## load *Tips* data

# %%
import seaborn
data = seaborn.load_dataset('tips')
data.shape
# Out:
# (244, 7)

# %% [markdown]
# # descriptive analysis: *Tips*

# %%
info(data)
# Out:
#                types  unique  magnitude  %nan  num_records
# variable
# sex         category     2.0        NaN   0.0          244
# smoker      category     2.0        NaN   0.0          244
# day         category     4.0        NaN   0.0          244
# time        category     2.0        NaN   0.0          244
# total_bill   float64     NaN        1.0   0.0          244
# tip          float64     NaN        0.0   0.0          244
# size           int64     6.0        NaN   0.0          244

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
#             count   mean   std   min    5%    25%   50%    75%    95%    max  \
# total_bill    244  19.79  8.90  3.07  9.56  13.35  17.8  24.13  38.06  50.81
# tip           244   3.00  1.38  1.00  1.44   2.00   2.9   3.56   5.20  10.00
# size          244   2.57  0.95  1.00  2.00   2.00   2.0   3.00   4.00   6.00
#
#             kurtosis  skew  uniform  gaussian  unimodal
# total_bill      1.17  1.13    False     False      True
# tip             3.55  1.46    False     False     False
# size            1.67  1.44    False     False     False

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data, max_size_cats = 6, alpha = .05)
dfc
# Out:
#        count unique  uniform  value0  value1 value2 value3 value4 value5  \
# var
# sex      244      2    False    Male  Female
# smoker   244      2    False      No     Yes
# day      244      4    False     Sat     Sun   Thur    Fri
# time     244      2    False  Dinner   Lunch
# size     244      6    False       2       3      4      5      6      1
#
#        %value0 %value1 %value2 %value3 %value4 %value5
# var
# sex      64.34   35.66
# smoker   61.89   38.11
# day      35.66   31.15   25.41    7.79
# time     72.13   27.87
# size     63.93   15.57   15.16    2.05    1.64    1.64

# %% [markdown]
# ### bivariate relationship

# %%
describe_bivariate(data)
# Out:
#      variable1   variable2 depend_corr_linear  corr_linear  corr_non_linear  \
# 0   total_bill         tip               True         0.62             0.46
# 1   total_bill        size               True         0.52             0.42
# 2          tip        size               True         0.41             0.29
# 0          sex      smoker                NaN          NaN              NaN
# 1          sex         day                NaN          NaN              NaN
# 2          sex        time                NaN          NaN              NaN
# 3       smoker         day                NaN          NaN              NaN
# 4       smoker        time                NaN          NaN              NaN
# 5          day        time                NaN          NaN              NaN
# 0          day        size                NaN          NaN              NaN
# 1          day         tip                NaN          NaN              NaN
# 2          day  total_bill                NaN          NaN              NaN
# 3          sex        size                NaN          NaN              NaN
# 4          sex         tip                NaN          NaN              NaN
# 5          sex  total_bill                NaN          NaN              NaN
# 6       smoker        size                NaN          NaN              NaN
# 7       smoker         tip                NaN          NaN              NaN
# 8       smoker  total_bill                NaN          NaN              NaN
# 9         time        size                NaN          NaN              NaN
# 10        time         tip                NaN          NaN              NaN
# 11        time  total_bill                NaN          NaN              NaN
#
#    depend_chi2 samples_same_dist_anova
# 0          NaN                     NaN
# 1          NaN                     NaN
# 2          NaN                     NaN
# 0        False                     NaN
# 1         True                     NaN
# 2         True                     NaN
# 3         True                     NaN
# 4        False                     NaN
# 5         True                     NaN
# 0          NaN                    True
# 1          NaN                    True
# 2          NaN                    True
# 3          NaN                   False
# 4          NaN                   False
# 5          NaN                   False
# 6          NaN                   False
# 7          NaN                   False
# 8          NaN                   False
# 9          NaN                    True
# 10         NaN                   False
# 11         NaN                    True

# %% [markdown]
# ---
# ## LOAD *Wine* data

# %%
from sklearn import datasets
df = datasets.load_wine()
data = pd.DataFrame(data= np.c_[df['data'], df['target']],columns= list(df['feature_names']) + ['target'])
data['target'] = data['target'].apply(lambda x: df['target_names'][int(x)])
data.shape
# Out:
# (178, 14)

# %% [markdown]
# # descriptive analysis: *Wine*

# %%
info(data)
# Out:
#                                 types  unique  magnitude  %nan  num_records
# variable
# alcohol                       float64     NaN        1.0   0.0          178
# malic_acid                    float64     NaN        0.0   0.0          178
# ash                           float64     NaN        0.0   0.0          178
# alcalinity_of_ash             float64     NaN        1.0   0.0          178
# magnesium                     float64     NaN        1.0   0.0          178
# total_phenols                 float64     NaN        0.0   0.0          178
# flavanoids                    float64     NaN        0.0   0.0          178
# nonflavanoid_phenols          float64     NaN       -1.0   0.0          178
# proanthocyanins               float64     NaN        0.0   0.0          178
# color_intensity               float64     NaN        0.0   0.0          178
# hue                           float64     NaN       -1.0   0.0          178
# od280/od315_of_diluted_wines  float64     NaN        0.0   0.0          178
# proline                       float64     NaN        2.0   0.0          178
# target                         object     3.0        NaN   0.0          178

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
#                               count    mean     std     min      5%     25%  \
# alcohol                         178   13.00    0.81   11.03   11.66   12.36
# malic_acid                      178    2.34    1.12    0.74    1.06    1.60
# ash                             178    2.37    0.27    1.36    1.92    2.21
# alcalinity_of_ash               178   19.49    3.34   10.60   14.77   17.20
# magnesium                       178   99.74   14.28   70.00   80.85   88.00
# total_phenols                   178    2.30    0.63    0.98    1.38    1.74
# flavanoids                      178    2.03    1.00    0.34    0.55    1.20
# nonflavanoid_phenols            178    0.36    0.12    0.13    0.19    0.27
# proanthocyanins                 178    1.59    0.57    0.41    0.73    1.25
# color_intensity                 178    5.06    2.32    1.28    2.11    3.22
# hue                             178    0.96    0.23    0.48    0.57    0.78
# od280/od315_of_diluted_wines    178    2.61    0.71    1.27    1.46    1.94
# proline                         178  746.89  314.91  278.00  354.55  500.50
#
#                                  50%     75%      95%      max  kurtosis  \
# alcohol                        13.05   13.68    14.22    14.83     -0.86
# malic_acid                      1.87    3.08     4.46     5.80      0.26
# ash                             2.36    2.56     2.74     3.23      1.08
# alcalinity_of_ash              19.50   21.50    25.00    30.00      0.44
# magnesium                      98.00  107.00   124.30   162.00      2.01
# total_phenols                   2.36    2.80     3.27     3.88     -0.85
# flavanoids                      2.13    2.88     3.50     5.08     -0.89
# nonflavanoid_phenols            0.34    0.44     0.60     0.66     -0.65
# proanthocyanins                 1.56    1.95     2.71     3.58      0.51
# color_intensity                 4.69    6.20     9.60    13.00      0.34
# hue                             0.96    1.12     1.28     1.71     -0.37
# od280/od315_of_diluted_wines    2.78    3.17     3.58     4.00     -1.09
# proline                       673.50  985.00  1297.25  1680.00     -0.27
#
#                               skew  uniform  gaussian  unimodal
# alcohol                      -0.05    False     False      True
# malic_acid                    1.03    False     False      True
# ash                          -0.18    False     False      True
# alcalinity_of_ash             0.21    False      True      True
# magnesium                     1.09    False     False      True
# total_phenols                 0.09    False     False      True
# flavanoids                    0.03    False     False     False
# nonflavanoid_phenols          0.45    False     False      True
# proanthocyanins               0.51    False     False      True
# color_intensity               0.86    False     False      True
# hue                           0.02    False     False      True
# od280/od315_of_diluted_wines -0.30     True     False      True
# proline                       0.76    False     False      True

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data, max_size_cats = 3, alpha = .05)
dfc
# Out:
#        count unique  uniform   value0   value1   value2 %value0 %value1  \
# var
# target   178      3     True  class_1  class_0  class_2   39.89   33.15
#
#        %value2
# var
# target   26.97

# %% [markdown]
# ### bivariate relationship

# %%
describe_bivariate(data)
# Out:
#                        variable1                     variable2  \
# 0                        alcohol                    malic_acid
# 1                        alcohol                           ash
# 2                        alcohol             alcalinity_of_ash
# 3                        alcohol                     magnesium
# 4                        alcohol                 total_phenols
# 5                        alcohol                    flavanoids
# 6                        alcohol          nonflavanoid_phenols
# 7                        alcohol               proanthocyanins
# 8                        alcohol               color_intensity
# 9                        alcohol                           hue
# 10                       alcohol  od280/od315_of_diluted_wines
# 11                       alcohol                       proline
# 12                    malic_acid                           ash
# 13                    malic_acid             alcalinity_of_ash
# 14                    malic_acid                     magnesium
# 15                    malic_acid                 total_phenols
# 16                    malic_acid                    flavanoids
# 17                    malic_acid          nonflavanoid_phenols
# 18                    malic_acid               proanthocyanins
# 19                    malic_acid               color_intensity
# 20                    malic_acid                           hue
# 21                    malic_acid  od280/od315_of_diluted_wines
# 22                    malic_acid                       proline
# 23                           ash             alcalinity_of_ash
# 24                           ash                     magnesium
# 25                           ash                 total_phenols
# 26                           ash                    flavanoids
# 27                           ash          nonflavanoid_phenols
# 28                           ash               proanthocyanins
# 29                           ash               color_intensity
# 30                           ash                           hue
# 31                           ash  od280/od315_of_diluted_wines
# 32                           ash                       proline
# 33             alcalinity_of_ash                     magnesium
# 34             alcalinity_of_ash                 total_phenols
# 35             alcalinity_of_ash                    flavanoids
# 36             alcalinity_of_ash          nonflavanoid_phenols
# 37             alcalinity_of_ash               proanthocyanins
# 38             alcalinity_of_ash               color_intensity
# 39             alcalinity_of_ash                           hue
# 40             alcalinity_of_ash  od280/od315_of_diluted_wines
# 41             alcalinity_of_ash                       proline
# 42                     magnesium                 total_phenols
# 43                     magnesium                    flavanoids
# 44                     magnesium          nonflavanoid_phenols
# 45                     magnesium               proanthocyanins
# 46                     magnesium               color_intensity
# 47                     magnesium                           hue
# 48                     magnesium  od280/od315_of_diluted_wines
# 49                     magnesium                       proline
# 50                 total_phenols                    flavanoids
# 51                 total_phenols          nonflavanoid_phenols
# 52                 total_phenols               proanthocyanins
# 53                 total_phenols               color_intensity
# 54                 total_phenols                           hue
# 55                 total_phenols  od280/od315_of_diluted_wines
# 56                 total_phenols                       proline
# 57                    flavanoids          nonflavanoid_phenols
# 58                    flavanoids               proanthocyanins
# 59                    flavanoids               color_intensity
# 60                    flavanoids                           hue
# 61                    flavanoids  od280/od315_of_diluted_wines
# 62                    flavanoids                       proline
# 63          nonflavanoid_phenols               proanthocyanins
# 64          nonflavanoid_phenols               color_intensity
# 65          nonflavanoid_phenols                           hue
# 66          nonflavanoid_phenols  od280/od315_of_diluted_wines
# 67          nonflavanoid_phenols                       proline
# 68               proanthocyanins               color_intensity
# 69               proanthocyanins                           hue
# 70               proanthocyanins  od280/od315_of_diluted_wines
# 71               proanthocyanins                       proline
# 72               color_intensity                           hue
# 73               color_intensity  od280/od315_of_diluted_wines
# 74               color_intensity                       proline
# 75                           hue  od280/od315_of_diluted_wines
# 76                           hue                       proline
# 77  od280/od315_of_diluted_wines                       proline
# 0                         target             alcalinity_of_ash
# 1                         target                       alcohol
# 2                         target                           ash
# 3                         target               color_intensity
# 4                         target                    flavanoids
# 5                         target                           hue
# 6                         target                     magnesium
# 7                         target                    malic_acid
# 8                         target          nonflavanoid_phenols
# 9                         target  od280/od315_of_diluted_wines
# 10                        target               proanthocyanins
# 11                        target                       proline
# 12                        target                 total_phenols
#
#    depend_corr_linear  corr_linear  corr_non_linear depend_chi2  \
# 0               False         0.09             0.31         NaN
# 1                True         0.29             0.21         NaN
# 2                True        -0.19             0.22         NaN
# 3                True         0.35             0.28         NaN
# 4                True         0.38             0.32         NaN
# 5                True         0.28             0.43         NaN
# 6               False        -0.15             0.19         NaN
# 7                True         0.26             0.26         NaN
# 8                True         0.56             0.50         NaN
# 9               False        -0.05             0.22         NaN
# 10              False         0.07             0.25         NaN
# 11               True         0.62             0.48         NaN
# 12               True         0.17             0.26         NaN
# 13               True         0.32             0.29         NaN
# 14              False         0.05             0.23         NaN
# 15               True        -0.29             0.33         NaN
# 16               True        -0.49             0.41         NaN
# 17               True         0.25             0.22         NaN
# 18               True        -0.41             0.32         NaN
# 19               True         0.35             0.25         NaN
# 20               True        -0.61             0.45         NaN
# 21               True        -0.42             0.26         NaN
# 22               True        -0.17             0.25         NaN
# 23               True         0.31             0.20         NaN
# 24               True         0.34             0.21         NaN
# 25              False         0.12             0.20         NaN
# 26              False         0.04             0.20         NaN
# 27              False         0.08             0.13         NaN
# 28              False         0.08             0.19         NaN
# 29               True         0.24             0.18         NaN
# 30              False        -0.01             0.15         NaN
# 31              False        -0.07             0.18         NaN
# 32               True         0.25             0.23         NaN
# 33               True        -0.18             0.17         NaN
# 34               True        -0.37             0.26         NaN
# 35               True        -0.45             0.29         NaN
# 36               True         0.34             0.23         NaN
# 37               True        -0.21             0.24         NaN
# 38              False        -0.03             0.21         NaN
# 39               True        -0.36             0.30         NaN
# 40               True        -0.36             0.23         NaN
# 41               True        -0.48             0.35         NaN
# 42               True         0.18             0.22         NaN
# 43               True         0.20             0.29         NaN
# 44               True        -0.20             0.14         NaN
# 45              False         0.07             0.16         NaN
# 46               True         0.41             0.26         NaN
# 47              False        -0.04             0.13         NaN
# 48              False         0.00             0.22         NaN
# 49               True         0.43             0.32         NaN
# 50               True         0.88             0.88         NaN
# 51               True        -0.43             0.30         NaN
# 52               True         0.66             0.56         NaN
# 53              False        -0.06             0.28         NaN
# 54               True         0.47             0.34         NaN
# 55               True         0.72             0.57         NaN
# 56               True         0.48             0.50         NaN
# 57               True        -0.58             0.41         NaN
# 58               True         0.75             0.62         NaN
# 59               True        -0.24             0.47         NaN
# 60               True         0.57             0.43         NaN
# 61               True         0.80             0.75         NaN
# 62               True         0.46             0.58         NaN
# 63               True        -0.39             0.24         NaN
# 64              False         0.08             0.18         NaN
# 65               True        -0.34             0.26         NaN
# 66               True        -0.59             0.44         NaN
# 67               True        -0.31             0.31         NaN
# 68              False        -0.02             0.24         NaN
# 69               True         0.42             0.30         NaN
# 70               True         0.62             0.46         NaN
# 71               True         0.32             0.26         NaN
# 72               True        -0.45             0.30         NaN
# 73               True        -0.39             0.33         NaN
# 74               True         0.33             0.33         NaN
# 75               True         0.61             0.49         NaN
# 76               True         0.25             0.27         NaN
# 77               True         0.33             0.32         NaN
# 0                 NaN          NaN              NaN         NaN
# 1                 NaN          NaN              NaN         NaN
# 2                 NaN          NaN              NaN         NaN
# 3                 NaN          NaN              NaN         NaN
# 4                 NaN          NaN              NaN         NaN
# 5                 NaN          NaN              NaN         NaN
# 6                 NaN          NaN              NaN         NaN
# 7                 NaN          NaN              NaN         NaN
# 8                 NaN          NaN              NaN         NaN
# 9                 NaN          NaN              NaN         NaN
# 10                NaN          NaN              NaN         NaN
# 11                NaN          NaN              NaN         NaN
# 12                NaN          NaN              NaN         NaN
#
#    samples_same_dist_anova
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# 32                     NaN
# 33                     NaN
# 34                     NaN
# 35                     NaN
# 36                     NaN
# 37                     NaN
# 38                     NaN
# 39                     NaN
# 40                     NaN
# 41                     NaN
# 42                     NaN
# 43                     NaN
# 44                     NaN
# 45                     NaN
# 46                     NaN
# 47                     NaN
# 48                     NaN
# 49                     NaN
# 50                     NaN
# 51                     NaN
# 52                     NaN
# 53                     NaN
# 54                     NaN
# 55                     NaN
# 56                     NaN
# 57                     NaN
# 58                     NaN
# 59                     NaN
# 60                     NaN
# 61                     NaN
# 62                     NaN
# 63                     NaN
# 64                     NaN
# 65                     NaN
# 66                     NaN
# 67                     NaN
# 68                     NaN
# 69                     NaN
# 70                     NaN
# 71                     NaN
# 72                     NaN
# 73                     NaN
# 74                     NaN
# 75                     NaN
# 76                     NaN
# 77                     NaN
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# 5                     True
# 6                     True
# 7                     True
# 8                     True
# 9                     True
# 10                    True
# 11                    True
# 12                    True

# %% [markdown]
# ---
# ## load *Weather* data

# %%
path = 'https://raw.githubusercontent.com/jmquintana79/utilsDS/master/scripts/datasets/data/dataset.weather.csv.gz'
data = pd.read_csv(path)
data['datetime'] = pd.to_datetime(data['datetime'])
data['dtnow'] = [datetime(2022,1,1,12,0,0) for i in range(len(data))]
data['dtrandom'] = pd.to_datetime(np.sort(np.random.choice(pd.date_range('2015-01-01', '2018-01-01', freq='H'), len(data), replace=False)))
data.shape
# Out:
# (17544, 16)

# %% [markdown]
# # descriptive analysis: *Weather*

# %%
info(data)
# Out:
#                                    types   unique  magnitude   %nan  \
# variable
# datetime                  datetime64[ns]  17544.0        NaN   0.00
# dtnow                     datetime64[ns]      1.0        NaN   0.00
# dtrandom                  datetime64[ns]  17544.0        NaN   0.00
# RH (%)                           float64      NaN        1.0   0.08
# WS (m/s)                         float64      NaN        0.0   0.06
# dew_point (degC)                 float64      NaN        1.0   0.08
# irradiation (MJ/m2)              float64      NaN        0.0  40.93
# local_press (hPa)                float64      NaN        3.0   0.00
# precipitation (mm)               float64      NaN        0.0  80.52
# sea-level pressure (hPa)         float64      NaN        3.0   0.00
# sunlight_duration (h)            float64      NaN        0.0  45.45
# temperature (degC)               float64      NaN        1.0   0.00
# vapor_press (hPa)                float64      NaN        1.0   0.08
# visibility (km)                  float64      NaN        1.0  70.83
# WD                                object     18.0        NaN   0.06
# cloud_coverage                    object     14.0        NaN  70.83
#
#                           num_records
# variable
# datetime                        17544
# dtnow                           17544
# dtrandom                        17544
# RH (%)                          17530
# WS (m/s)                        17533
# dew_point (degC)                17530
# irradiation (MJ/m2)             10364
# local_press (hPa)               17544
# precipitation (mm)               3417
# sea-level pressure (hPa)        17544
# sunlight_duration (h)            9570
# temperature (degC)              17544
# vapor_press (hPa)               17530
# visibility (km)                  5117
# WD                              17533
# cloud_coverage                   5117

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
#                           count     mean    std    min      5%      25%  \
# RH (%)                    17530    68.47  20.44   13.0    34.0    53.00
# WS (m/s)                  17533     2.83   1.43    0.0     1.0     1.80
# dew_point (degC)          17530     9.77  10.32  -20.1    -7.2     0.90
# irradiation (MJ/m2)       10364     0.92   0.94    0.0     0.0     0.11
# local_press (hPa)         17544  1010.94   7.52  965.5   998.5  1005.90
# precipitation (mm)         3417     0.94   2.21    0.0     0.0     0.00
# sea-level pressure (hPa)  17544  1013.82   7.58  968.2  1001.4  1008.70
# sunlight_duration (h)      9570     0.41   0.43    0.0     0.0     0.00
# temperature (degC)        17544    16.17   8.18   -2.2     3.6     9.00
# vapor_press (hPa)         17530    14.62   8.82    1.2     3.6     6.50
# visibility (km)            5117    17.90   7.69    0.9     5.0    15.00
#
#                               50%      75%      95%      max  kurtosis  skew  \
# RH (%)                      70.00    85.00    99.00   100.00     -0.89 -0.22
# WS (m/s)                     2.50     3.60     5.60    12.20      1.76  1.12
# dew_point (degC)            10.70    19.30    23.90    27.30     -1.14 -0.24
# irradiation (MJ/m2)          0.59     1.58     2.83     3.71     -0.26  0.91
# local_press (hPa)         1011.00  1016.30  1022.90  1031.30      0.38 -0.30
# precipitation (mm)           0.00     1.00     4.60    40.00     45.60  5.14
# sea-level pressure (hPa)  1013.90  1019.20  1025.90  1034.40      0.36 -0.29
# sunlight_duration (h)        0.20     1.00     1.00     1.00     -1.65  0.37
# temperature (degC)          16.40    23.00    28.70    37.30     -1.11 -0.01
# vapor_press (hPa)           12.80    22.30    29.70    36.30     -1.16  0.40
# visibility (km)             20.00    20.00    30.00    50.00      0.66  0.40
#
#                           uniform  gaussian  unimodal
# RH (%)                      False     False      True
# WS (m/s)                    False     False      True
# dew_point (degC)            False     False      True
# irradiation (MJ/m2)         False     False     False
# local_press (hPa)           False     False      True
# precipitation (mm)          False     False     False
# sea-level pressure (hPa)    False     False      True
# sunlight_duration (h)       False     False     False
# temperature (degC)          False     False      True
# vapor_press (hPa)           False     False      True
# visibility (km)             False     False     False

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data, max_size_cats = 17, alpha = .05)
dfc
# Out:
#                 count unique  uniform value0 value1 value2 value3 value4  \
# var
# WD              17533     17    False    NNW     NW      S    SSE    NNE
# cloud_coverage   5117     13    False    10-     10     0+      0      9
#
#                value5 value6 value7 value8 value9 value10 value11 value12  \
# var
# WD                  N     NE    SSW     SE    ENE     WNW       E     ESE
# cloud_coverage      1      8      2      3      7       6       4       5
#
#                value13 value14 value15 value16 %value0 %value1 %value2  \
# var
# WD                  SW       W     WSW       C   15.21   13.43   10.26
# cloud_coverage                                   32.21   21.91    9.71
#
#                %value3 %value4 %value5 %value6 %value7 %value8 %value9  \
# var
# WD                 9.9    7.21    7.07    6.78    5.27    5.26    4.92
# cloud_coverage    7.64    4.34    3.93    3.89    3.79    3.17    3.01
#
#                %value10 %value11 %value12 %value13 %value14 %value15 %value16
# var
# WD                 4.81     2.89     2.15     1.76     1.52     1.49     0.07
# cloud_coverage      2.7     2.05     1.66

# %% [markdown]
# ### datetimes

# %%
dfdt = describe_datetime(data)
dfdt
# Out:
#           count unique       most_frequent num_most_frequent  \
# datetime  17544  17544                 NaT               NaN
# dtnow     17544      1 2022-01-01 12:00:00             17544
# dtrandom  17544  17544                 NaT               NaN
#
#                        first                last    most_frequent_td  \
# datetime 2016-01-01 00:00:00 2017-12-31 23:00:00  (0 days 01:00:00,)
# dtnow    2022-01-01 12:00:00 2022-01-01 12:00:00  (0 days 00:00:00,)
# dtrandom 2015-01-01 01:00:00 2017-12-31 23:00:00  (0 days 01:00:00,)
#
#           %most_frequent_td  num_td
# datetime             100.00       1
# dtnow                100.00       1
# dtrandom              66.58       9

# %% [markdown]
# ### bivariate relationships

# %%
describe_bivariate(data, size_max_sample=500)
# Out:
# /Users/juan/miniconda3/envs/analysis/lib/python3.7/site-packages/scipy/stats/morestats.py:1306: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /Users/juan/miniconda3/envs/analysis/lib/python3.7/site-packages/scipy/stats/morestats.py:1306: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /Users/juan/miniconda3/envs/analysis/lib/python3.7/site-packages/scipy/stats/morestats.py:1306: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /Users/juan/miniconda3/envs/analysis/lib/python3.7/site-packages/scipy/stats/morestats.py:1306: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /Users/juan/miniconda3/envs/analysis/lib/python3.7/site-packages/scipy/stats/morestats.py:1306: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /Users/juan/miniconda3/envs/analysis/lib/python3.7/site-packages/scipy/stats/morestats.py:1306: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /Users/juan/miniconda3/envs/analysis/lib/python3.7/site-packages/scipy/stats/morestats.py:1306: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
#                    variable1                 variable2 depend_corr_linear  \
# 0                     RH (%)                  WS (m/s)               True
# 1                     RH (%)          dew_point (degC)               True
# 2                     RH (%)       irradiation (MJ/m2)               True
# 3                     RH (%)         local_press (hPa)               True
# 4                     RH (%)        precipitation (mm)               True
# 5                     RH (%)  sea-level pressure (hPa)               True
# 6                     RH (%)     sunlight_duration (h)               True
# 7                     RH (%)        temperature (degC)               True
# 8                     RH (%)         vapor_press (hPa)               True
# 9                     RH (%)           visibility (km)               True
# 10                  WS (m/s)          dew_point (degC)              False
# 11                  WS (m/s)       irradiation (MJ/m2)               True
# 12                  WS (m/s)         local_press (hPa)               True
# 13                  WS (m/s)        precipitation (mm)              False
# 14                  WS (m/s)  sea-level pressure (hPa)               True
# 15                  WS (m/s)     sunlight_duration (h)               True
# 16                  WS (m/s)        temperature (degC)               True
# 17                  WS (m/s)         vapor_press (hPa)              False
# 18                  WS (m/s)           visibility (km)              False
# 19          dew_point (degC)       irradiation (MJ/m2)              False
# 20          dew_point (degC)         local_press (hPa)               True
# 21          dew_point (degC)        precipitation (mm)              False
# 22          dew_point (degC)  sea-level pressure (hPa)               True
# 23          dew_point (degC)     sunlight_duration (h)               True
# 24          dew_point (degC)        temperature (degC)               True
# 25          dew_point (degC)         vapor_press (hPa)               True
# 26          dew_point (degC)           visibility (km)               True
# 27       irradiation (MJ/m2)         local_press (hPa)              False
# 28       irradiation (MJ/m2)        precipitation (mm)              False
# 29       irradiation (MJ/m2)  sea-level pressure (hPa)              False
# 30       irradiation (MJ/m2)     sunlight_duration (h)               True
# 31       irradiation (MJ/m2)        temperature (degC)               True
# 32       irradiation (MJ/m2)         vapor_press (hPa)              False
# 33       irradiation (MJ/m2)           visibility (km)              False
# 34         local_press (hPa)        precipitation (mm)              False
# 35         local_press (hPa)  sea-level pressure (hPa)               True
# 36         local_press (hPa)     sunlight_duration (h)              False
# 37         local_press (hPa)        temperature (degC)               True
# 38         local_press (hPa)         vapor_press (hPa)               True
# 39         local_press (hPa)           visibility (km)              False
# 40        precipitation (mm)  sea-level pressure (hPa)              False
# 41        precipitation (mm)     sunlight_duration (h)              False
# 42        precipitation (mm)        temperature (degC)              False
# 43        precipitation (mm)         vapor_press (hPa)              False
# 44        precipitation (mm)           visibility (km)              False
# 45  sea-level pressure (hPa)     sunlight_duration (h)              False
# 46  sea-level pressure (hPa)        temperature (degC)               True
# 47  sea-level pressure (hPa)         vapor_press (hPa)               True
# 48  sea-level pressure (hPa)           visibility (km)              False
# 49     sunlight_duration (h)        temperature (degC)              False
# 50     sunlight_duration (h)         vapor_press (hPa)               True
# 51     sunlight_duration (h)           visibility (km)               True
# 52        temperature (degC)         vapor_press (hPa)               True
# 53        temperature (degC)           visibility (km)              False
# 54         vapor_press (hPa)           visibility (km)               True
# 0                         WD            cloud_coverage                NaN
# 0                         WD                    RH (%)                NaN
# 1                         WD                  WS (m/s)                NaN
# 2                         WD          dew_point (degC)                NaN
# 3                         WD       irradiation (MJ/m2)                NaN
# 4                         WD         local_press (hPa)                NaN
# 5                         WD        precipitation (mm)                NaN
# 6                         WD  sea-level pressure (hPa)                NaN
# 7                         WD     sunlight_duration (h)                NaN
# 8                         WD        temperature (degC)                NaN
# 9                         WD         vapor_press (hPa)                NaN
# 10                        WD           visibility (km)                NaN
# 11            cloud_coverage                    RH (%)                NaN
# 12            cloud_coverage                  WS (m/s)                NaN
# 13            cloud_coverage          dew_point (degC)                NaN
# 14            cloud_coverage       irradiation (MJ/m2)                NaN
# 15            cloud_coverage         local_press (hPa)                NaN
# 16            cloud_coverage        precipitation (mm)                NaN
# 17            cloud_coverage  sea-level pressure (hPa)                NaN
# 18            cloud_coverage     sunlight_duration (h)                NaN
# 19            cloud_coverage        temperature (degC)                NaN
# 20            cloud_coverage         vapor_press (hPa)                NaN
# 21            cloud_coverage           visibility (km)                NaN
#
#     corr_linear  corr_non_linear depend_chi2 samples_same_dist_anova
# 0         -0.28             0.13         NaN                     NaN
# 1          0.68             0.42         NaN                     NaN
# 2         -0.54             0.35         NaN                     NaN
# 3         -0.23             0.17         NaN                     NaN
# 4          0.55             0.40         NaN                     NaN
# 5         -0.24             0.17         NaN                     NaN
# 6         -0.63             0.42         NaN                     NaN
# 7          0.28             0.23         NaN                     NaN
# 8          0.62             0.41         NaN                     NaN
# 9         -0.49             0.31         NaN                     NaN
# 10        -0.02             0.15         NaN                     NaN
# 11         0.22             0.17         NaN                     NaN
# 12        -0.17             0.15         NaN                     NaN
# 13         0.02             0.18         NaN                     NaN
# 14        -0.17             0.14         NaN                     NaN
# 15         0.14             0.13         NaN                     NaN
# 16         0.15             0.15         NaN                     NaN
# 17         0.00             0.15         NaN                     NaN
# 18         0.11             0.18         NaN                     NaN
# 19        -0.07             0.18         NaN                     NaN
# 20        -0.43             0.30         NaN                     NaN
# 21        -0.01             0.24         NaN                     NaN
# 22        -0.43             0.31         NaN                     NaN
# 23        -0.32             0.22         NaN                     NaN
# 24         0.89             0.77         NaN                     NaN
# 25         0.97             1.00         NaN                     NaN
# 26        -0.25             0.28         NaN                     NaN
# 27        -0.00             0.17         NaN                     NaN
# 28        -0.19             0.24         NaN                     NaN
# 29        -0.01             0.17         NaN                     NaN
# 30         0.74             0.60         NaN                     NaN
# 31         0.28             0.25         NaN                     NaN
# 32        -0.06             0.18         NaN                     NaN
# 33         0.21             0.24         NaN                     NaN
# 34         0.03             0.23         NaN                     NaN
# 35         1.00             1.00         NaN                     NaN
# 36         0.09             0.17         NaN                     NaN
# 37        -0.43             0.30         NaN                     NaN
# 38        -0.46             0.30         NaN                     NaN
# 39         0.15             0.23         NaN                     NaN
# 40         0.04             0.22         NaN                     NaN
# 41        -0.13             0.04         NaN                     NaN
# 42        -0.19             0.24         NaN                     NaN
# 43        -0.01             0.25         NaN                     NaN
# 44        -0.28             0.18         NaN                     NaN
# 45         0.11             0.17         NaN                     NaN
# 46        -0.44             0.31         NaN                     NaN
# 47        -0.47             0.30         NaN                     NaN
# 48         0.12             0.23         NaN                     NaN
# 49         0.02             0.22         NaN                     NaN
# 50        -0.27             0.22         NaN                     NaN
# 51         0.29             0.17         NaN                     NaN
# 52         0.89             0.76         NaN                     NaN
# 53        -0.08             0.22         NaN                     NaN
# 54        -0.24             0.29         NaN                     NaN
# 0           NaN              NaN        True                     NaN
# 0           NaN              NaN         NaN                    True
# 1           NaN              NaN         NaN                    True
# 2           NaN              NaN         NaN                    True
# 3           NaN              NaN         NaN                    True
# 4           NaN              NaN         NaN                    True
# 5           NaN              NaN         NaN                    True
# 6           NaN              NaN         NaN                    True
# 7           NaN              NaN         NaN                    True
# 8           NaN              NaN         NaN                    True
# 9           NaN              NaN         NaN                    True
# 10          NaN              NaN         NaN                    True
# 11          NaN              NaN         NaN                    True
# 12          NaN              NaN         NaN                    True
# 13          NaN              NaN         NaN                    True
# 14          NaN              NaN         NaN                    True
# 15          NaN              NaN         NaN                    True
# 16          NaN              NaN         NaN                    True
# 17          NaN              NaN         NaN                    True
# 18          NaN              NaN         NaN                    True
# 19          NaN              NaN         NaN                    True
# 20          NaN              NaN         NaN                    True
# 21          NaN              NaN         NaN                    True
